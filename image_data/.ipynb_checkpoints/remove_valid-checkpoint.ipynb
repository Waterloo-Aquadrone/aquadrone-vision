# %%
import os

# %%
# !ls
# Out:
#  1119_images_final			      obj_not_in_order
#  1119_images_final_test			      remove_aug_valid.ipynb
#  1200_images_combined			      remove_every_other_frame.ipynb
#  1200_images_renamed_final		      rename_files.ipynb
#  aug_1119_images_final_test		      rename_gate_path_gate_path.ipynb
#  augment.ipynb				      split_video.ipynb
#  final_labels_skipped_104_total_1119.csv      test.txt
#  images					      test_labels.csv
#  images_exclude_safe			      train.txt
#  images_removed_every_other_frame_1000_safe   train_test_txt.ipynb
#  load_csv_remove_skipped_files_test.ipynb     train_valid
#  obj					     'video src'
#  obj.data				      yolo_labels
#  obj.names

# %%
dir_path = "yolo_labels/valid"
img_list = os.listdir(dir_path)
# img_list.pop(0)
# img_list.pop(0)
print(len(img_list))
img_list
# Out:
# 109
# ['gate_0.txt',
#  'gate_1.txt',
#  'gate_100.txt',
#  'gate_101.txt',
#  'gate_102.txt',
#  'gate_103.txt',
#  'gate_104.txt',
#  'gate_105.txt',
#  'gate_106.txt',
#  'gate_109.txt',
#  'gate_11.txt',
#  'gate_110.txt',
#  'gate_111.txt',
#  'gate_112.txt',
#  'gate_113.txt',
#  'gate_114.txt',
#  'gate_115.txt',
#  'gate_116.txt',
#  'gate_117.txt',
#  'gate_119.txt',
#  'gate_12.txt',
#  'gate_122.txt',
#  'gate_125.txt',
#  'gate_127.txt',
#  'gate_13.txt',
#  'gate_20.txt',
#  'gate_23.txt',
#  'gate_26.txt',
#  'gate_3.txt',
#  'gate_32.txt',
#  'gate_36.txt',
#  'gate_4.txt',
#  'gate_40.txt',
#  'gate_45.txt',
#  'gate_46.txt',
#  'gate_48.txt',
#  'gate_49.txt',
#  'gate_5.txt',
#  'gate_50.txt',
#  'gate_51.txt',
#  'gate_52.txt',
#  'gate_53.txt',
#  'gate_55.txt',
#  'gate_56.txt',
#  'gate_57.txt',
#  'gate_58.txt',
#  'gate_6.txt',
#  'gate_60.txt',
#  'gate_61.txt',
#  'gate_62.txt',
#  'gate_63.txt',
#  'gate_64.txt',
#  'gate_65.txt',
#  'gate_66.txt',
#  'gate_67.txt',
#  'gate_68.txt',
#  'gate_69.txt',
#  'gate_7.txt',
#  'gate_70.txt',
#  'gate_71.txt',
#  'gate_72.txt',
#  'gate_73.txt',
#  'gate_74.txt',
#  'gate_75.txt',
#  'gate_76.txt',
#  'gate_77.txt',
#  'gate_78.txt',
#  'gate_79.txt',
#  'gate_8.txt',
#  'gate_80.txt',
#  'gate_81.txt',
#  'gate_82.txt',
#  'gate_83.txt',
#  'gate_84.txt',
#  'gate_85.txt',
#  'gate_86.txt',
#  'gate_87.txt',
#  'gate_88.txt',
#  'gate_89.txt',
#  'gate_9.txt',
#  'gate_90.txt',
#  'gate_91.txt',
#  'gate_92.txt',
#  'gate_93.txt',
#  'gate_94.txt',
#  'gate_95.txt',
#  'gate_96.txt',
#  'gate_97.txt',
#  'gate_98.txt',
#  'gate_99.txt',
#  'gate_path_63.txt',
#  'gate_path_64.txt',
#  'gate_path_65.txt',
#  'gate_path_66.txt',
#  'gate_path_67.txt',
#  'gate_path_68.txt',
#  'gate_path_69.txt',
#  'gate_path_70.txt',
#  'gate_path_71.txt',
#  'path_643.txt',
#  'path_644.txt',
#  'path_645.txt',
#  'path_646.txt',
#  'path_647.txt',
#  'path_648.txt',
#  'path_649.txt',
#  'path_650.txt',
#  'path_651.txt',
#  'path_652.txt']

# %% [markdown]
# # To remove txt if there

# %%
dir_path = "train_valid/train_real_no_txt"
for name in img_list:
#     txt_name = os.path.splitext(name)[0] + ".txt"
    os.remove(os.path.join(dir_path, txt_name))
img_list
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-69-3b3e27cb5ae9> in <module>
#       2 for name in img_list:
#       3     txt_name = os.path.splitext(name)[0] + ".txt"
# ----> 4     os.remove(os.path.join(dir_path, txt_name))
#       5 img_list
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train_valid/train_real_no_txt/aug_gate_0.txt'

# %%
dir_path = "train_valid/valid_no_txt"
img_list = os.listdir(dir_path)
img_list.pop(0)
# img_list.pop(0)
print(len(img_list))
img_list
# Out:
# 109
# ['gate_0.jpg',
#  'gate_1.jpg',
#  'gate_100.jpg',
#  'gate_101.jpg',
#  'gate_102.jpg',
#  'gate_103.jpg',
#  'gate_104.jpg',
#  'gate_105.jpg',
#  'gate_106.jpg',
#  'gate_109.jpg',
#  'gate_11.jpg',
#  'gate_110.jpg',
#  'gate_111.jpg',
#  'gate_112.jpg',
#  'gate_113.jpg',
#  'gate_114.jpg',
#  'gate_115.jpg',
#  'gate_116.jpg',
#  'gate_117.jpg',
#  'gate_119.jpg',
#  'gate_12.jpg',
#  'gate_122.jpg',
#  'gate_125.jpg',
#  'gate_127.jpg',
#  'gate_13.jpg',
#  'gate_20.jpg',
#  'gate_23.jpg',
#  'gate_26.jpg',
#  'gate_3.jpg',
#  'gate_32.jpg',
#  'gate_36.jpg',
#  'gate_4.jpg',
#  'gate_40.jpg',
#  'gate_45.jpg',
#  'gate_46.jpg',
#  'gate_48.jpg',
#  'gate_49.jpg',
#  'gate_5.jpg',
#  'gate_50.jpg',
#  'gate_51.jpg',
#  'gate_52.jpg',
#  'gate_53.jpg',
#  'gate_55.jpg',
#  'gate_56.jpg',
#  'gate_57.jpg',
#  'gate_58.jpg',
#  'gate_6.jpg',
#  'gate_60.jpg',
#  'gate_61.jpg',
#  'gate_62.jpg',
#  'gate_63.jpg',
#  'gate_64.jpg',
#  'gate_65.jpg',
#  'gate_66.jpg',
#  'gate_67.jpg',
#  'gate_68.jpg',
#  'gate_69.jpg',
#  'gate_7.jpg',
#  'gate_70.jpg',
#  'gate_71.jpg',
#  'gate_72.jpg',
#  'gate_73.jpg',
#  'gate_74.jpg',
#  'gate_75.jpg',
#  'gate_76.jpg',
#  'gate_77.jpg',
#  'gate_78.jpg',
#  'gate_79.jpg',
#  'gate_8.jpg',
#  'gate_80.jpg',
#  'gate_81.jpg',
#  'gate_82.jpg',
#  'gate_83.jpg',
#  'gate_84.jpg',
#  'gate_85.jpg',
#  'gate_86.jpg',
#  'gate_87.jpg',
#  'gate_88.jpg',
#  'gate_89.jpg',
#  'gate_9.jpg',
#  'gate_90.jpg',
#  'gate_91.jpg',
#  'gate_92.jpg',
#  'gate_93.jpg',
#  'gate_94.jpg',
#  'gate_95.jpg',
#  'gate_96.jpg',
#  'gate_97.jpg',
#  'gate_98.jpg',
#  'gate_99.jpg',
#  'gate_path_63.jpg',
#  'gate_path_64.jpg',
#  'gate_path_65.jpg',
#  'gate_path_66.jpg',
#  'gate_path_67.jpg',
#  'gate_path_68.jpg',
#  'gate_path_69.jpg',
#  'gate_path_70.jpg',
#  'gate_path_71.jpg',
#  'path_643.jpg',
#  'path_644.jpg',
#  'path_645.jpg',
#  'path_646.jpg',
#  'path_647.jpg',
#  'path_648.jpg',
#  'path_649.jpg',
#  'path_650.jpg',
#  'path_651.jpg',
#  'path_652.jpg']

# %%
for i in range(len(img_list)):
    img_list[i] = "aug_" + img_list[i]
#     img_name = os.path.splitext(img_list[i])
#     os.remove(os.path.join(aug_dir_path, img_list[i]))
img_list
# Out:
# ['aug_gate_0.jpg',
#  'aug_gate_1.jpg',
#  'aug_gate_100.jpg',
#  'aug_gate_101.jpg',
#  'aug_gate_102.jpg',
#  'aug_gate_103.jpg',
#  'aug_gate_104.jpg',
#  'aug_gate_105.jpg',
#  'aug_gate_106.jpg',
#  'aug_gate_109.jpg',
#  'aug_gate_11.jpg',
#  'aug_gate_110.jpg',
#  'aug_gate_111.jpg',
#  'aug_gate_112.jpg',
#  'aug_gate_113.jpg',
#  'aug_gate_114.jpg',
#  'aug_gate_115.jpg',
#  'aug_gate_116.jpg',
#  'aug_gate_117.jpg',
#  'aug_gate_119.jpg',
#  'aug_gate_12.jpg',
#  'aug_gate_122.jpg',
#  'aug_gate_125.jpg',
#  'aug_gate_127.jpg',
#  'aug_gate_13.jpg',
#  'aug_gate_20.jpg',
#  'aug_gate_23.jpg',
#  'aug_gate_26.jpg',
#  'aug_gate_3.jpg',
#  'aug_gate_32.jpg',
#  'aug_gate_36.jpg',
#  'aug_gate_4.jpg',
#  'aug_gate_40.jpg',
#  'aug_gate_45.jpg',
#  'aug_gate_46.jpg',
#  'aug_gate_48.jpg',
#  'aug_gate_49.jpg',
#  'aug_gate_5.jpg',
#  'aug_gate_50.jpg',
#  'aug_gate_51.jpg',
#  'aug_gate_52.jpg',
#  'aug_gate_53.jpg',
#  'aug_gate_55.jpg',
#  'aug_gate_56.jpg',
#  'aug_gate_57.jpg',
#  'aug_gate_58.jpg',
#  'aug_gate_6.jpg',
#  'aug_gate_60.jpg',
#  'aug_gate_61.jpg',
#  'aug_gate_62.jpg',
#  'aug_gate_63.jpg',
#  'aug_gate_64.jpg',
#  'aug_gate_65.jpg',
#  'aug_gate_66.jpg',
#  'aug_gate_67.jpg',
#  'aug_gate_68.jpg',
#  'aug_gate_69.jpg',
#  'aug_gate_7.jpg',
#  'aug_gate_70.jpg',
#  'aug_gate_71.jpg',
#  'aug_gate_72.jpg',
#  'aug_gate_73.jpg',
#  'aug_gate_74.jpg',
#  'aug_gate_75.jpg',
#  'aug_gate_76.jpg',
#  'aug_gate_77.jpg',
#  'aug_gate_78.jpg',
#  'aug_gate_79.jpg',
#  'aug_gate_8.jpg',
#  'aug_gate_80.jpg',
#  'aug_gate_81.jpg',
#  'aug_gate_82.jpg',
#  'aug_gate_83.jpg',
#  'aug_gate_84.jpg',
#  'aug_gate_85.jpg',
#  'aug_gate_86.jpg',
#  'aug_gate_87.jpg',
#  'aug_gate_88.jpg',
#  'aug_gate_89.jpg',
#  'aug_gate_9.jpg',
#  'aug_gate_90.jpg',
#  'aug_gate_91.jpg',
#  'aug_gate_92.jpg',
#  'aug_gate_93.jpg',
#  'aug_gate_94.jpg',
#  'aug_gate_95.jpg',
#  'aug_gate_96.jpg',
#  'aug_gate_97.jpg',
#  'aug_gate_98.jpg',
#  'aug_gate_99.jpg',
#  'aug_gate_path_63.jpg',
#  'aug_gate_path_64.jpg',
#  'aug_gate_path_65.jpg',
#  'aug_gate_path_66.jpg',
#  'aug_gate_path_67.jpg',
#  'aug_gate_path_68.jpg',
#  'aug_gate_path_69.jpg',
#  'aug_gate_path_70.jpg',
#  'aug_gate_path_71.jpg',
#  'aug_path_643.jpg',
#  'aug_path_644.jpg',
#  'aug_path_645.jpg',
#  'aug_path_646.jpg',
#  'aug_path_647.jpg',
#  'aug_path_648.jpg',
#  'aug_path_649.jpg',
#  'aug_path_650.jpg',
#  'aug_path_651.jpg',
#  'aug_path_652.jpg']

# %%
txt_list = []
for i in range(len(img_list)):
    img_name = os.path.splitext(img_list[i])[0] + '.txt'
    txt_list.append(img_name)
txt_list
# Out:
# ['aug_gate_0.txt',
#  'aug_gate_1.txt',
#  'aug_gate_100.txt',
#  'aug_gate_101.txt',
#  'aug_gate_102.txt',
#  'aug_gate_103.txt',
#  'aug_gate_104.txt',
#  'aug_gate_105.txt',
#  'aug_gate_106.txt',
#  'aug_gate_109.txt',
#  'aug_gate_11.txt',
#  'aug_gate_110.txt',
#  'aug_gate_111.txt',
#  'aug_gate_112.txt',
#  'aug_gate_113.txt',
#  'aug_gate_114.txt',
#  'aug_gate_115.txt',
#  'aug_gate_116.txt',
#  'aug_gate_117.txt',
#  'aug_gate_119.txt',
#  'aug_gate_12.txt',
#  'aug_gate_122.txt',
#  'aug_gate_125.txt',
#  'aug_gate_127.txt',
#  'aug_gate_13.txt',
#  'aug_gate_20.txt',
#  'aug_gate_23.txt',
#  'aug_gate_26.txt',
#  'aug_gate_3.txt',
#  'aug_gate_32.txt',
#  'aug_gate_36.txt',
#  'aug_gate_4.txt',
#  'aug_gate_40.txt',
#  'aug_gate_45.txt',
#  'aug_gate_46.txt',
#  'aug_gate_48.txt',
#  'aug_gate_49.txt',
#  'aug_gate_5.txt',
#  'aug_gate_50.txt',
#  'aug_gate_51.txt',
#  'aug_gate_52.txt',
#  'aug_gate_53.txt',
#  'aug_gate_55.txt',
#  'aug_gate_56.txt',
#  'aug_gate_57.txt',
#  'aug_gate_58.txt',
#  'aug_gate_6.txt',
#  'aug_gate_60.txt',
#  'aug_gate_61.txt',
#  'aug_gate_62.txt',
#  'aug_gate_63.txt',
#  'aug_gate_64.txt',
#  'aug_gate_65.txt',
#  'aug_gate_66.txt',
#  'aug_gate_67.txt',
#  'aug_gate_68.txt',
#  'aug_gate_69.txt',
#  'aug_gate_7.txt',
#  'aug_gate_70.txt',
#  'aug_gate_71.txt',
#  'aug_gate_72.txt',
#  'aug_gate_73.txt',
#  'aug_gate_74.txt',
#  'aug_gate_75.txt',
#  'aug_gate_76.txt',
#  'aug_gate_77.txt',
#  'aug_gate_78.txt',
#  'aug_gate_79.txt',
#  'aug_gate_8.txt',
#  'aug_gate_80.txt',
#  'aug_gate_81.txt',
#  'aug_gate_82.txt',
#  'aug_gate_83.txt',
#  'aug_gate_84.txt',
#  'aug_gate_85.txt',
#  'aug_gate_86.txt',
#  'aug_gate_87.txt',
#  'aug_gate_88.txt',
#  'aug_gate_89.txt',
#  'aug_gate_9.txt',
#  'aug_gate_90.txt',
#  'aug_gate_91.txt',
#  'aug_gate_92.txt',
#  'aug_gate_93.txt',
#  'aug_gate_94.txt',
#  'aug_gate_95.txt',
#  'aug_gate_96.txt',
#  'aug_gate_97.txt',
#  'aug_gate_98.txt',
#  'aug_gate_99.txt',
#  'aug_gate_path_63.txt',
#  'aug_gate_path_64.txt',
#  'aug_gate_path_65.txt',
#  'aug_gate_path_66.txt',
#  'aug_gate_path_67.txt',
#  'aug_gate_path_68.txt',
#  'aug_gate_path_69.txt',
#  'aug_gate_path_70.txt',
#  'aug_gate_path_71.txt',
#  'aug_path_643.txt',
#  'aug_path_644.txt',
#  'aug_path_645.txt',
#  'aug_path_646.txt',
#  'aug_path_647.txt',
#  'aug_path_648.txt',
#  'aug_path_649.txt',
#  'aug_path_650.txt',
#  'aug_path_651.txt',
#  'aug_path_652.txt']

# %%
print(len(txt_list))
print(len(img_list))
# Out:
# 109
# 109

# %% [markdown]
# # Attempting to remove validation files

# %%
aug_dir_path = "aug_1119_images_final_test/val_removed_images"
aug_dir_path_txt = "aug_1119_images_final_test/val_removed_labels"

# %%
for i in range(len(img_list)):
    path = os.path.join(aug_dir_path, img_list[i])
    if os.path.isfile(path):
        os.remove(os.path.join(aug_dir_path, img_list[i]))

# %%
for i in range(len(img_list)):
    path = os.path.join(aug_dir_path_txt, txt_list[i])
    if os.path.isfile(path):
        os.remove(os.path.join(aug_dir_path_txt, txt_list[i]))
